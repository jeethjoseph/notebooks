# %%
#Packages
import pandas as pd

# %%
#data exlporation
data = pd.read_csv('Data/1LakhFMCGSalesWithCategory.csv', names = ['BillId','ItemId','ItemName','Level1','Level2','Level3','Level4','Level5','Level6'] )

# %%
data['dummy'] = 1

# %%
data = data.dropna()

# %%
matrix = data.pivot_table(values='dummy',index ='BillId', columns ='ItemName').fillna(0)
matrix.head()
# Out:
# ItemName  110PELLETS SUGAR FREE GOLD  555 DETERGENT POWDER 500GM  \
# BillId
# 129                              0.0                         0.0
# 177                              0.0                         0.0
# 179                              0.0                         0.0
# 1214                             0.0                         0.0
# 1216                             0.0                         0.0
#
# ItemName  7 O CLOCK BLADE SUPER PLAT 1  ACT II CLASSIC SALTED 40GM 1X40GM  \
# BillId
# 129                                0.0                                0.0
# 177                                0.0                                0.0
# 179                                0.0                                0.0
# 1214                               0.0                                0.0
# 1216                               0.0                                0.0
#
# ItemName  ACT II DIET POP CORN 0.6 LESS SALT 70GM  \
# BillId
# ...

# %%
matrix.any().any() > 1
# Out:
# False

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
frequent_itemsets = apriori(matrix, min_support=0.005, use_colnames=True)

# %%
frequent_itemsets.tail()
# Out:
#      support                           itemsets
# 27  0.013295  (SPRING LEAVES LYCHEE DRINK 1LTR)
# 28  0.009475                 (VICKS COUGH DROP)
# 29  0.005058                   (VICKS INHALLER)
# 30  0.005746               (VICKS VAPORUB 10GM)
# 31  0.006250               (VICKS VAPORUB 25GM)

# %%
frequent_itemsets.shape
# Out:
# (32, 2)

# %%
frequent_itemsets
# Out:
#      support                                    itemsets
# 0   0.006418                        (BISLERI WATER 1LTR)
# 1   0.005058                       (BOROLINE CREAM 20GM)
# 2   0.005884                    (BOROLINE CREAM JAR 7GM)
# 3   0.008344              (BRITANNIA BISC BOURBON 120GM)
# 4   0.007794            (BRITANNIA BISC MARIE GOLD 89GM)
# 5   0.007060             (BRITANNIA BISC NICE TIME 73GM)
# 6   0.006143    (BRITANNIA BISC NUTRI C DIGESTIVE 100GM)
# 7   0.006556                 (BRITANNIA CAKE FRUIT 90GM)
# 8   0.006755                   (BRITANNIA CAKE VEG 60GM)
# 9   0.006693          (CADBURY'S CHOC DAIRY MILK 12.5GM)
# 10  0.006281             (CADBURY'S CHOC FIVE STAR 12GM)
# 11  0.006953           (CADBURY'S CHOC FIVE STAR 25.8GM)
# 12  0.011660           (COLGATE PASTE STRONG TEETH 30GM)
# 13  0.005838            (DETTOL ANTISEPTIC LIQUID 110ML)
# 14  0.006678            (DETTOL ANTISEPTIC LIQUID 500ML)
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.tail()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []
